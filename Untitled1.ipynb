# %%
import pandas as pd
train_data2  = pd.read_excel('Data_Train.xlsx')
train_data = train_data2[train_data2.Kilometers_Driven<6499999].copy()
brand_name=[]
model_name=[]
version=[]
for i,j in train_data.iterrows():
    brand_name.append(j['Name'].split()[0].lower())
    model_name.append("".join(j['Name'].split()[1:3]).lower())
    version.append("".join(j['Name'].split()[2:]).lower())
    #print(j['Name'].split()[0]," ",j['Name'].split()[1]," ","".join(j['Name'].split()[2:]))
train_data['Brand'] = brand_name
train_data['Model'] = model_name
train_data['Version'] = version
#train_data['is_19']=train_data.Year.apply(lambda x: 1 if x<2000 else 0)
train_data['Year_Modified'] = train_data.Year.apply(lambda x: 2019-x)
#train_data = train_data.sort_values(by=['Name'])
#train_data["Price"] = train_data["Price"].apply(np.log)

# %%
train_data1  = pd.read_excel('Data_Test.xlsx')
df_all_rows = pd.concat([ train_data2,train_data1])

# %%
train_data1
# Out:
#                                                    Name    Location  Year  \
# 0                               Maruti Alto K10 LXI CNG       Delhi  2014
# 1                         Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2             Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                                  Toyota Etios Liva GD   Hyderabad  2012
# 4                                     Hyundai i20 Magna      Mumbai  2014
# 5                                Mahindra XUV500 W8 2WD  Coimbatore  2016
# 6                   Toyota Fortuner 4x2 AT TRD Sportivo        Pune  2015
# 7                                  Hyundai EON Era Plus      Jaipur  2013
# 8                                   Honda City 1.5 S MT      Mumbai  2011
# 9                                Mahindra XUV500 W6 2WD  Coimbatore  2015
# 10                            Audi Q5 2008-2012 2.0 TDI      Mumbai  2012
# 11                              Hyundai Grand i10 Magna      Jaipur  2016
# ...

# %%
import pandas as pd
# train_data2  = pd.read_excel('Data_Train.xlsx')
# train_data = train_data2[train_data2.Kilometers_Driven<6499999].copy()
brand_name=[]
model_name=[]
version=[]
for i,j in df_all_rows.iterrows():
    brand_name.append(j['Name'].split()[0].lower())
    model_name.append("".join(j['Name'].split()[1:3]).lower())
    version.append("".join(j['Name'].split()[2:]).lower())
    #print(j['Name'].split()[0]," ",j['Name'].split()[1]," ","".join(j['Name'].split()[2:]))
df_all_rows['Brand'] = brand_name
df_all_rows['Model'] = model_name
df_all_rows['Version'] = version
#train_data['is_19']=train_data.Year.apply(lambda x: 1 if x<2000 else 0)
df_all_rows['Year_Modified'] = df_all_rows.Year.apply(lambda x: 2019-x)
#df_all_rows = df_all_rows.sort_values(by=['Name'])
#train_data["Price"] = train_data["Price"].apply(np.log)

# %%
df_all_rows[6019:]
# Out:
#        Engine Fuel_Type  Kilometers_Driven    Location      Mileage  \
# 0      998 CC       CNG              40929       Delhi  32.26 km/kg
# 1      796 CC    Petrol              54493  Coimbatore    24.7 kmpl
# 2     2393 CC    Diesel              34000      Mumbai   13.68 kmpl
# 3     1364 CC    Diesel             139000   Hyderabad   23.59 kmpl
# 4     1197 CC    Petrol              29000      Mumbai    18.5 kmpl
# 5     2179 CC    Diesel              85609  Coimbatore    16.0 kmpl
# 6     2982 CC    Diesel              59000        Pune   12.55 kmpl
# 7      814 CC    Petrol              65000      Jaipur    21.1 kmpl
# 8     1497 CC    Petrol              66000      Mumbai    17.0 kmpl
# 9     2179 CC    Diesel              54684  Coimbatore    15.1 kmpl
# 10    1968 CC    Diesel              78000      Mumbai    12.8 kmpl
# 11    1197 CC    Petrol              21000      Jaipur    18.9 kmpl
# 12    1794 CC    Petrol              90000     Chennai    13.4 kmpl
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_all_rows['Brand'])
df_all_rows['Brand_Transformed']  = le.transform(df_all_rows['Brand'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_all_rows['Model'])
df_all_rows['Model_Transformed']  = le.transform(df_all_rows['Model'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_all_rows['Version'])
df_all_rows['Version_Transformed']  = le.transform(df_all_rows['Version'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_all_rows['Location'])
df_all_rows['Location_Transformed']  = le.transform(df_all_rows['Location'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_all_rows['Transmission'])
df_all_rows['Transmission_Transformed']  = le.transform(df_all_rows['Transmission'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_all_rows['Location'])
df_all_rows['Location_Transformed']  = le.transform(df_all_rows['Location'])

# %%
df_all_rows = pd.concat([df_all_rows,pd.get_dummies(df_all_rows['Location'], prefix='Location')],axis=1)
df_all_rows = pd.concat([df_all_rows,pd.get_dummies(df_all_rows['Year'], prefix='Year')],axis=1)
df_all_rows = pd.concat([df_all_rows,pd.get_dummies(df_all_rows['Transmission'], prefix='Transmission')],axis=1)
df_all_rows = pd.concat([df_all_rows,pd.get_dummies(df_all_rows['Fuel_Type'], prefix='Fuel_Type')],axis=1)

# %%
df_all_rows['is_audi_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='audi') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_bmw_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='bmw') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_bentley_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='bentley') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_ford_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='ford') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_jaguar_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='jaguar') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_lambhorgini_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='lamborghini') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_landrover_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='land') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_benz_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='benz') & (x['Price']>45)) else 0,axis=1)
df_all_rows['is_porsche_highend1']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='porsche') & (x['Price']>45)) else 0,axis=1)

# %%
df_all_rows['is_audi_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='audi') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_bmw_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='bmw') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_bentley_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='bentley') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_ford_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='ford') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_honda_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='honda') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_hyundai_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='hyundai') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_isuzu_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='isuzu') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_jeep_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='jeep') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_mahindra_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='mahindra') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_mini_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='mini') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_mitsubishi_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='mitsubishi') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_renault_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='renault') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_skoda_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='skoda') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_tata_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='tata') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_toyota_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='toyota') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_volkswagen_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='volkswagen') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_volvo_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='volvo') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_jaguar_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='jaguar') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_lambhorgini_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='lamborghini') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_landrover_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='land') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_benz_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='benz') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
df_all_rows['is_porsche_highend']=df_all_rows[['Brand','Price']].apply(lambda x: 1 if ((x['Brand']=='porsche') & ((x['Price']>12.5) & (x['Price']<45))) else 0,axis=1)
# df_all_rows['2000_2005']=df_all_rows.Year.apply(lambda x: 1 if (x>=2000 & x<2005) else 0)
# df_all_rows['2005_2010']=df_all_rows.Year.apply(lambda x: 1 if (x>=2005 & x<2010) else 0)
# df_all_rows['2010_2015']=df_all_rows.Year.apply(lambda x: 1 if (x>=2010 & x<2015) else 0)
# df_all_rows['2015_above']=df_all_rows.Year.apply(lambda x: 1 if x>=2015else 0)
df_all_rows['Below_2000']=df_all_rows.Year.apply(lambda x: 1 if x<2000 else 0)
df_all_rows['2000_2005']=df_all_rows.Year.apply(lambda x: 1 if (x>=2000 & x<2005) else 0)
df_all_rows['2005_2010']=df_all_rows.Year.apply(lambda x: 1 if (x>=2005 & x<2010) else 0)
df_all_rows['2010_2015']=df_all_rows.Year.apply(lambda x: 1 if (x>=2010 & x<2015) else 0)
df_all_rows['2015_above']=df_all_rows.Year.apply(lambda x: 1 if x>=2015else 0)

# %%
df_all_rows['Below_2000']=df_all_rows.Year.apply(lambda x: 1 if x<2000 else 0)
df_all_rows['2000_2005']=df_all_rows.Year.apply(lambda x: 1 if (x>=2000 & x<2005) else 0)
df_all_rows['2005_2010']=df_all_rows.Year.apply(lambda x: 1 if (x>=2005 & x<2010) else 0)
df_all_rows['2010_2015']=df_all_rows.Year.apply(lambda x: 1 if (x>=2010 & x<2015) else 0)
df_all_rows['2015_above']=df_all_rows.Year.apply(lambda x: 1 if x>=2015else 0)

# %%
from sklearn.preprocessing import MinMaxScaler
for i in ['Kilometers_Driven']:
    df_all_rows[i] = MinMaxScaler(feature_range=(0,1)).fit_transform(df_all_rows[i].values.astype(float).reshape(-1,1))

# %%
train_data1=df_all_rows[:6019].copy()
test_data1=df_all_rows[6019:].copy()

# %%
test_data1=
# Out:
#        Engine Fuel_Type  Kilometers_Driven    Location      Mileage  \
# 0      998 CC       CNG           0.006271       Delhi  32.26 km/kg
# 1      796 CC    Petrol           0.008357  Coimbatore    24.7 kmpl
# 2     2393 CC    Diesel           0.005205      Mumbai   13.68 kmpl
# 3     1364 CC    Diesel           0.021359   Hyderabad   23.59 kmpl
# 4     1197 CC    Petrol           0.004435      Mumbai    18.5 kmpl
# 5     2179 CC    Diesel           0.013145  Coimbatore    16.0 kmpl
# 6     2982 CC    Diesel           0.009051        Pune   12.55 kmpl
# 7      814 CC    Petrol           0.009974      Jaipur    21.1 kmpl
# 8     1497 CC    Petrol           0.010128      Mumbai    17.0 kmpl
# 9     2179 CC    Diesel           0.008387  Coimbatore    15.1 kmpl
# 10    1968 CC    Diesel           0.011974      Mumbai    12.8 kmpl
# 11    1197 CC    Petrol           0.003205      Jaipur    18.9 kmpl
# 12    1794 CC    Petrol           0.013820     Chennai    13.4 kmpl
# ...

# %%
train_data1 = train_data.copy()

# %%
from sklearn.model_selection import train_test_split
data_train_target = train_data1['Price']
#data_train_final = train_data1['Year']
data_train_final = train_data1.drop(['Name',
 'Location','Version_Transformed','Fuel_Type','Year','Transmission',
 'Transmission_Transformed',
 'Owner_Type',
 'Mileage',
 'Engine',
 'Power',
 'Seats',
 'New_Price',
 'Price',
 'Brand',
 'Model',
 'Version',
 'Location_Transformed'],axis=1)
#X_train, X_test, y_train, y_test = train_test_split(data_train_final, data_train_target, test_size=0.33)

# %%
from sklearn.model_selection import train_test_split
data_test_target = test_data1['Price']
#data_train_final = train_data1['Year']
data_test_final = test_data1.drop(['Name',
 'Location','Version_Transformed','Fuel_Type','Year','Transmission',
 'Transmission_Transformed',
 'Owner_Type',
 'Mileage',
 'Engine',
 'Power',
 'Seats',
 'New_Price',
 'Price',
 'Brand',
 'Model',
 'Version',
 'Location_Transformed'],axis=1)
#X_train, X_test, y_train, y_test = train_test_split(data_train_final, data_train_target, test_size=0.33)

# %% [markdown]
# <h2>Model</h2>

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
hyperparameters1 = dict(n_estimators=[1, 2, 4, 8, 16, 32, 64, 100, 200],max_depth=np.linspace(1, 32, 32, endpoint=True),min_samples_split = np.linspace(0.1, 1.0, 10, endpoint=True),min_samples_leaf = np.linspace(0.1, 0.5, 5, endpoint=True))
clf1=RandomizedSearchCV(RandomForestRegressor(), hyperparameters1, random_state=1, cv=5, verbose=0,scoring='neg_mean_squared_error')
best_model1 = clf1.fit(data_train_final, data_train_target)

# %%
best_model1.best_params_
# Out:
# {'n_estimators': 32,
#  'min_samples_split': 0.1,
#  'min_samples_leaf': 0.1,
#  'max_depth': 3.0}

# %%
clf2= RandomForestRegressor(n_estimators=32,
 min_samples_split= 0.1,
 min_samples_leaf= 0.1,
 max_depth=3.0)
clf2.fit(data_train_final, data_train_target)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3.0,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=0.1, min_samples_split=0.1,
#            min_weight_fraction_leaf=0.0, n_estimators=32, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred12 = clf2.predict(data_train_final)
rmsle(y_pred12,data_train_target)
# Out:
# 0.5423007146135828

# %%
data_train_final['rf_op'] = y_pred12

# %%
import warnings
import xgboost as xgb
import csv as csv
from xgboost import plot_importance
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
warnings.simplefilter(action='ignore', category=FutureWarning)
parameters_for_testing = {
   'colsample_bytree':[0.4,0.6,0.8],
   'gamma':[0,0.03,0.1,0.3],
   'min_child_weight':[1.5,6,10],
   'learning_rate':[0.1,0.07],
   'max_depth':[3,5,7,9],
   'n_estimators':[1, 2, 4, 8, 16, 32, 64, 100, 200],
   'reg_alpha':[1e-5, 1e-2,  0.75],
   'reg_lambda':[1e-5, 1e-2, 0.45],
   'subsample':[0.6,0.95]
}
clf=RandomizedSearchCV(xgb.XGBRegressor(), parameters_for_testing, random_state=1, cv=5, verbose=0,scoring='neg_mean_squared_error')
# xgb = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
#                            colsample_bytree=1, max_depth=7)
best_model = clf.fit(data_train_final, data_train_target)
best_model.best_params_

best_xgb_model = xgb.XGBRegressor(colsample_bytree=best_model.best_params_['colsample_bytree'],
                 gamma=best_model.best_params_['gamma'],                 
                 learning_rate=best_model.best_params_['learning_rate'],
                 max_depth=best_model.best_params_['max_depth'],
                 min_child_weight=best_model.best_params_['min_child_weight'],
                 n_estimators=best_model.best_params_['n_estimators'],                                                                    
                 reg_alpha=best_model.best_params_['reg_alpha'],
                 reg_lambda=best_model.best_params_['reg_lambda'],
                 subsample=best_model.best_params_['subsample'])
best_xgb_model.fit(data_train_final, data_train_target)
#y_pred = best_xgb_model.predict(X_test)
# y_predict=clf1.predict(X_test_ohe)
#rms = sqrt(mean_squared_error(y_test, y_pred))
#print('RMS: ',rms,' R2 Score:',r2_score(y_test, y_pred))
# Out:
# [11:17:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:18:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:18:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:18:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:18:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:18:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
y_train1 = best_xgb_model.predict(data_train_final)
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
# y_predict=clf1.predict(X_test_ohe)
rms = sqrt(mean_squared_error(data_train_target, y_train1))
print('RMS: ',rms,' R2 Score:',r2_score(data_train_target, y_train1))
# Out:
# RMS:  2.788193486939186  R2 Score: 0.9378817093666216

# %%
pd.DataFrame(y_train1).to_csv("Train_set_pred.csv")

# %%
import numpy as np

def rmsle(h, y): 
    """
    Compute the Root Mean Squared Log Error for hypthesis h and targets y
    
    Args:
        h - numpy array containing predictions with shape (n_samples, n_targets)
        y - numpy array containing targets with shape (n_samples, n_targets)
    """
    return np.sqrt(np.square(np.log(h + 1) - np.log(y + 1)).mean())

rmsle(y_train1,data_train_target)
# Out:
# 0.2067480905747819

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=[15,15]
xgb.plot_importance(best_xgb_model)

# %%
y_pred = best_xgb_model.predict(data_test_final)

# %%
pd.DataFrame(y_pred).to_excel('Test_Predictions.xlsx')
